# %%
# HIDDEN
from ipywidgets import widgets, interact, Dropdown,SelectMultiple, Checkbox,VBox,FloatSlider,Button,dlink,link
from IPython.display import display
#https://stackoverflow.com/questions/18398929/passing-multiple-variables-from-dropdowns-using-django-python
#https://towardsdatascience.com/bring-your-jupyter-notebook-to-life-with-interactive-widgets-bc12e03f0916
#https://medium.com/@jdchipox/how-to-interact-with-jupyter-33a98686f24e
#https://stackoverflow.com/questions/26352555/how-does-one-get-widget-values-with-a-button-in-ipython
#https://elc.github.io/posts/embed-interactive-notebooks/

# %%
# HIDDEN 
import numpy as np
import pandas as pd

# %%
listofcheckboxes = {'no preferences':[0],'fruits':['FAT'],'vegetables':['DGR','DGC'],
     'legumes':['DBR','DBC','DFR','DFC'],'grains':['AC','AC_wg','DAR','DAC',
     'AI','AI_wg','AA','AA_wg','AF','AF_wg','AD','AD_wg','AC','AC_wg'],'nuts_seeds':
     ['GAT'],'milk':['BAE','BAH','BAK','BLS','BLM','BLH','BLF','BN'],
     'vegetarianproducts':['BAV','BNV','VEG'],
     'fish':['JAC', 'JAR', 'JCC', 'JCR', 'JKC', 'JKR', 'JMC', 'JMR', 'JRC'],
    'meat':['MBGR','MBGC','MACR','MACC','MAER','MECC','MECR','MEER','MEEC','MAIC','MAIR','MAE',\
    'MAIR','MAIC','MCOR','MCOC','MCAR','MCAC','MAGR','MAGC','MAHR','MAHC',
    'MI','MAAC','MAAR'],'eggs_oil':['CA','OA', 'OC', 'OE','BTM','BJC']}

# %%
df1 = pd.read_pickle('CH_aug.p')

# %%
foodgroups = widgets.Dropdown(options = listofcheckboxes.keys())

# %%
foodgroups
# Out:
# Dropdown(options=('no preferences', 'fruits', 'vegetables', 'legumes', 'grains', 'nuts_seeds', 'milk', 'vegeta…

# %%
# HIDDEN
# OLD
def multi_checkbox_widget(descriptions):
    """ Widget with a search field and lots of checkboxes """
    #search_widget = widgets.Text()
    options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}
    options = [options_dict[description] for description in descriptions]
    options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})
    #options_widget = widgets.HBox(options, layout={'width': 'max-content'})
    #multi_select = widgets.VBox([search_widget, options_widget])
    mass_dict = {description: widgets.IntSlider(description='Mass (grams)', min=0,
                max = 1000,step=50,value=0,disabled=False) for description in descriptions}
    mass = [mass_dict[description] for description in descriptions]
    mass_widget = widgets.VBox(mass, layout={'overflow': 'scroll'})
    multi_select = widgets.HBox(children = [options_widget,mass_widget], layout={'overflow': 'scroll'})
    #multi_select = widgets.VBox([options_widget])

    # Wire the search field to the checkboxes
    ##def on_text_change(change):
    ##    search_input = change['new']
    ##    if search_input == '':
            # Reset search field
    ##        new_options = [options_dict[description] for description in descriptions]
    ##    else:
            # Filter by search field using difflib.
    ##        close_matches = difflib.get_close_matches(search_input, descriptions, cutoff=0.0)
    ##        new_options = [options_dict[description] for description in close_matches]
    ##    options_widget.children = new_options

    #search_widget.observe(on_text_change, names='value')
    return multi_select
# words = list(set([i.split(',')[0] for i in df1[df1['Group']=='FAT']['Food Name'].tolist()]))
# widget = multi_checkbox_widget(words)
# [widget.description for widget in widget.children[1].children if widget.value]

# %%
def on_text_change():
    #foodgroups = widgets.Dropdown(options = listofcheckboxes.keys())
    #foodgroups
    search_input = foodgroups.value
    if search_input == 'no preferences':
        multi_select = 'No Food Preferences, Continue to calculate lowest impact diet'
        
    
    else:          
        descriptions = [i for i in df1[df1['Group'].isin(listofcheckboxes[foodgroups.value])]['Food Name']][0:5]
        options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}
        options = [options_dict[description] for description in descriptions]
        options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})              
        #multi_widget = widgets.HBox(children = [foodgroups,options_widget])
        
        mass_dict = {description: widgets.IntSlider(description='Mass (grams)', min=0,
                max = 1000,step=50,value=0,disabled=False) for description in descriptions}
        mass = [mass_dict[description] for description in descriptions]
        mass_widget = widgets.VBox(mass, layout={'overflow': 'scroll'})
        multi_select = widgets.HBox(children = [options_widget,mass_widget], layout={'overflow': 'scroll'})
    foodgroups.observe(on_text_change(), names='value')
    return multi_select
#on_text_change(foodgroups.value)

# %%
on_text_change()
# Out:
# Exception ignored in: <bound method Widget.__del__ of IntSlider(value=0, description='Mass (grams)', max=1000, step=50)>
# Traceback (most recent call last):
#   File "/home/walkerch/miniconda3/envs/new_environment/lib/python3.6/site-packages/ipywidgets/widgets/widget.py", line 417, in __del__
#     def __del__(self):
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-408a22638ca9> in <module>
# ----> 1 on_text_change()
#
# <ipython-input-28-4798f20cc299> in on_text_change()
#      20         mass_widget = widgets.VBox(mass, layout={'overflow': 'scroll'})
#      21         multi_select = widgets.HBox(children = [options_widget,mass_widget], layout={'overflow': 'scroll'})
# ---> 22     foodgroups.observe(on_text_change(), names='value')
#      23     return multi_select
#      24 #on_text_change(foodgroups.value)
#
# ...

# %%
foodgroups
# Out:
# Dropdown(index=1, options=('no preferences', 'fruits', 'vegetables', 'legumes', 'grains', 'nuts_seeds', 'milk'…

# %%
def selectfoods():
    descriptions = [i for i in df1[df1['Group'].isin(listofcheckboxes[foodgroups.value])]['Food Name']][0:5]
    options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                        description in descriptions}
    options = [options_dict[description] for description in descriptions]
    options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})
    return options_widget

# %%
options_widget

# %%
options_widget.observe(selectfoods, names='value' )

# %%
descriptions = [options_widget.description for options_widget in options_widget.children if options_widget.value]

# %%
mass_dict = {description: widgets.IntSlider(description='Mass (grams)', min=0,
                max = 1000,step=50,value=0,disabled=False) for description in descriptions}

# %%
[options_widget.description for options_widget in options_widget.children if options_widget.value]

# %%
close_matches = [(options_widget.value,options_widget.description) for options_widget in options_widget.children]

# %%
close_matches

# %%
box.children[1].layout.visibility = 'hidden'
box.children[2].layout.visibility = 'hidden'

txtArea = wd.Textarea()
display(txtArea)

def show(b):
    box.children[1].layout.visibility = 'visible'
    box.children[2].layout.visibility = 'visible'

# %% [raw]
# #Generate a dummy list
# Allfileslist = ["{}".format(x) for x in range(600)]
# #Search box + generate ALL the checkboxes, this seems to be the bottleneck
# search_widget = widgets.Text(placeholder='Type for older experiments',                 description= 'Search:')
# # experiments = {eachfilename: widgets.Checkbox(description=eachfilename, value=False) for eachfilename in Allfileslist}
# experiments = {}
# options_widget = widgets.VBox(layout={'overflow': 'auto'})
# mass_dict = {description: widgets.IntSlider(description='Mass (grams)', min=0,
#                 max = 1000,step=50,value=0,disabled=False) for description in descriptions}
# mass = [mass_dict[description] for description in descriptions]
# mass_widget = widgets.VBox(mass, layout={'overflow': 'scroll'})
# multi_select = widgets.HBox(description =print(foodgroups.value),\
#                         children = [options_widget,mass_widget], layout={'overflow': 'scroll'})
#
# def whentextischanged (change):
#     """Dynamically update the widget experiments"""
#     search_input = change['new']
#     if len([options_widget.description for options_widget in options_widget.children if options_widget.value])==0:
#         # Reset search field, default to last 9 experiments
#         new_options = 0
#     else:
#         # Filter by search
#         close_matches = [(options_widget.value,options_widget.description) for options_widget in options_widget.children]
#
#         for name in close_matches:
#             if name[0] ==True:
#                 options_widget.children[1].layout.visibility = 'visible'
#             else:
#                 options_widget.children[1].layout.visibility = 'hidden'
#         ### magic code that generates only the match boxes ###
#         new_options = mass_widget
#
#     options_widget.children = new_options

# %%
#Generate a dummy list
Allfileslist = list(zip(df1['Food Name'],df1['Group']))
#Search box + generate ALL the checkboxes, this seems to be the bottleneck
search_widget = widgets.Dropdown(options = listofcheckboxes.keys(),layout={'width': 'initial'})
#display(search_widget)
experiments = {}
experiments_mass = {}
options_widget = widgets.VBox(layout={'overflow': 'auto'})
mass_widget = widgets.VBox(layout={'overflow': 'auto'})
def whentextischanged (change):
    """Dynamically update the widget experiments"""
    search_input = change['new']
    if search_input == 'no preferences':
        # Reset search field, default to last 9 experiments
        new_options = [widgets.Checkbox(description='Proceed with optimization', value=True)]
        new_options_mass = [widgets.Checkbox(description='Proceed with optimization', value=True)]
    else:
        # Filter by search
        close_matches = [x[0] for x in Allfileslist if x[1] in(listofcheckboxes[search_widget.value])][0:5]
        for name in close_matches:
            if name not in experiments:
                experiments[name] = widgets.Checkbox(description=name, value=False,style={'description_width': 'initial'})
                experiments_mass[name] = widgets.IntSlider(description='Mass (grams)', min=0,max=500,step=50,value=0)
        ### magic code that generates only the match boxes ###
        new_options = [experiments[eachfilename] for eachfilename in close_matches]
        new_options_mass = [experiments_mass[eachfilename] for eachfilename in close_matches]
    options_widget.children = new_options
    mass_widget.children = new_options_mass

# %%
#multi_select.children[2].layout.visibility = 'hidden'

# %%
#multi_select.children[2].layout.visibility = 'visible'

# %%
#Generate the vbox, search
multi_select = widgets.HBox([search_widget, options_widget,mass_widget])
search_widget.observe(whentextischanged, names='value')
#serve it up
multi_select

# %%
[multi_select.description for multi_select in multi_select.children[1].children if multi_select.value]
# Out:
# ['apples, eating, raw, flesh and skin, weighed with core',
#  'apricots, raw, flesh and skin, weighed with stones, frozen']

# %%
[multi_select.value for multi_select in multi_select.children[2].children if multi_select.value]
# Out:
# [150, 150]

# %%
nutstest= [i for i in multi_select.children]
nutstest
# Out:
# [Dropdown(index=5, options=('no preferences', 'fruits', 'vegetables', 'legumes', 'grains', 'nuts_seeds', 'milk', 'vegetarianproducts', 'fish', 'meat', 'eggs_oil'), value='nuts_seeds'),
# ...

# %%
multi_select.children[1].children
# Out:
# (Checkbox(value=True, description='almonds, flaked and ground'),
#  Checkbox(value=False, description='almonds, toasted'),
#  Checkbox(value=False, description='sunflower seeds'),
#  Checkbox(value=False, description='sunflower seeds, toasted'),
#  Checkbox(value=False, description='barcelona nuts, kernel only'))

# %%
[multi_select.description for multi_select in multi_select.children[1].children if multi_select.value]
# Out:
# ['almonds, flaked and ground']

# %%
multi_select.children[0]
# Out:
# Dropdown(index=5, options=('no preferences', 'fruits', 'vegetables', 'legumes', 'grains', 'nuts_seeds', 'milk'…

# %%
[i for i in multi_select.children]
# Out:
# [Dropdown(index=5, options=('no preferences', 'fruits', 'vegetables', 'legumes', 'grains', 'nuts_seeds', 'milk', 'vegetarianproducts', 'fish', 'meat', 'eggs_oil'), value='nuts_seeds'),
# ...

# %%
selectedfoods = {}

# %%
# HIDDEN

def joinlists(widgetname):
    global selectedfoods
    rs1 = [widgetname.description for widgetname in widgetname.children[1].children if widgetname.value]
    rs2 = list(range(len(rs1)))#[widgetname.value for widgetname in widgetname.children[1].children if widgetname.value]
    food = list(zip(rs1,rs2))
    
    try:
        food
        for j in food:
            selectedfoods[j[0].split(',')[0]] = {}#'names'
            selectedfoods[j[0].split(',')[0]]['names']=j[0]
            selectedfoods[j[0].split(',')[0]]['mass']=j[1]
    except NameError:
        i= None   
    return #selectedfoods

# %%
joinlists(multi_select)

# %%
selectedfoods
# Out:
# {'apples': {'names': 'apples, eating, raw, flesh and skin, weighed with core',
#   'mass': 0},
#  'artichoke': {'names': 'artichoke, globe, base of leaves and heart, boiled in unsalted water',
#   'mass': 0},
#  'asparagus': {'names': 'asparagus, raw', 'mass': 1}}

# %%
[i for i in multi_select.children]
# Out:
# [Dropdown(index=3, options=('no preferences', 'fruits', 'vegetables', 'legumes', 'grains', 'nuts_seeds', 'milk', 'vegetarianproducts', 'fish', 'meat', 'eggs_oil'), value='legumes'),
# ...

# %%
fruitstest
# Out:
# [Dropdown(index=1, options=('no preferences', 'fruits', 'vegetables', 'legumes', 'grains', 'nuts_seeds', 'milk', 'vegetarianproducts', 'fish', 'meat', 'eggs_oil'), value='fruits'),
# ...

# %%
multi_select.children[1].layout.visibility = 'hidden'

def show(b):
    multi_select.children[1].layout.visibility = 'visible'

# %%
for i in [options_widget.value for options_widget in options_widget.children]:
    if i==True:
        mass_widget
    else:
        multi_select = widgets.HBox(description =print(foodgroups.value),\
                        children = [options_widget,mass_widget], layout={'overflow': 'scroll'})

# %%
descriptions = [i for i in df1[df1['Group'].isin(listofcheckboxes['fruits'])]['Food Name']][0:5]
options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}
options = [options_dict[description] for description in descriptions]
options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})

# %%
options_widget

# %%
#checked = [options_widget.description for options_widget in options_widget.children if options_widget.value]

# %%
#for i in [(options_widget.description,options_widget.value) for options_widget in options_widget.children ]:
#    print(i[0],':', i[1])

# %%
descriptions = [i for i in df1[df1['Group'].isin(listofcheckboxes['fruits'])]['Food Name']][0:5]
options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}
options = [options_dict[description] for description in descriptions]
options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})

# %%
options_widget

# %%
mass_widget = widgets.IntSlider(description='Mass (grams)', min=0,max = 1000,step=50,value=0,disabled=False)

# %%
int_range = widgets.IntSlider()
display(int_range)

# %%
out = widgets.Output()

# %%
def my_function(x,y):

# %%
@interact(x=5,y='Python')
def my_function(x,y):
    return(x,y)

# %%
cb1 = Checkbox(description='1')
cb2 = Checkbox(description='2')
cb3 = Checkbox(description='3')

vb = VBox(children = [cb1, cb2, cb3])
top_toggle = Checkbox(description='Remove 3')

def remove_3(button):
    if button['new']:
        vb.children = [cb1, cb2]
    else:
        vb.children = [cb1, cb2, cb3]

top_toggle.observe(remove_3, names='value')
display(top_toggle)
display(vb)

# %%
descriptions = [i for i in df1[df1['Group'].isin(listofcheckboxes['fruits'])]['Food Name']][0:5]
options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}
options = [options_dict[description] for description in descriptions]
options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})
mass_dict = {description: widgets.IntSlider(description='Mass (grams)', min=0,
                max = 1000,step=50,value=0,disabled=False) for description in descriptions}
mass = [mass_dict[description] for description in descriptions]
mass_widget = widgets.VBox(mass, layout={'overflow': 'scroll'})
multi_select = widgets.HBox(description =print(foodgroups.value),\
                children = [options_widget,mass_widget], layout={'overflow': 'scroll'})

# %%
[(options_widget.value,options_widget.description)\
                            for options_widget in options_widget.children if options_widget.value]

# %%
[multi_select.descriptions for multi_select.]

# %%
multi_select

# %%
for i,j in zip(descriptions,multi_select):
    print (i)

# %%
def masstest(b):
    for i in descriptions:

# %%
multi_select.children[1].layout.visibility = 'hidden'

def show(b):
    multi_select.children[1].layout.visibility = 'visible'

# %%
multi_select.children[1].observe(show)

# %%
multi_select

# %%
#testing adding button and textbox
from ipywidgets import widgets as wd
from ipywidgets import Layout, Box
from IPython.display import display

btnLayout = Layout(flex='1 1 auto', width='auto')

btns= [
    wd.Button(description="Add Route"),
    wd.Button(description="234"),
    wd.Button(description="411")
]

box_layout = Layout(display='flex',
                    flex_flow='row',
                    align_items='stretch')

box = Box(children=btns, layout=box_layout)

display(box)
box.children[1].layout.visibility = 'hidden'
box.children[2].layout.visibility = 'hidden'

txtArea = wd.Textarea()
display(txtArea)

def show(b):
    box.children[1].layout.visibility = 'visible'
    box.children[2].layout.visibility = 'visible'

#function intended to append button value/description to textArea
def add_text(b):
    txtArea.value = b.description + txtArea.value

box.children[0].on_click(show)
box.children[1].on_click(add_text)
box.children[2].on_click(add_text)

# %%
def on_value_change(change):
    with out:
        print(change['new'])

# %%
options_widget.observe(on_value_change,'value')

# %%
options_widget

# %%
options_widget

# %%
mass_widget = widgets.IntSlider(description='Mass (grams)', min=0,
            max = 1000,step=50,value=0,disabled=False)

# %%
mass_widget

# %%
mass_dict = {description: widgets.IntSlider(description='Mass (grams)', min=0,
            max = 1000,step=50,value=0,disabled=False) for description in descriptions}
mass = [mass_dict[description] for description in descriptions]
mass_widget = widgets.VBox(mass, layout={'overflow': 'scroll'})

# %%
options_widget

# %%
options_widget

# %%
        
for enu,i in enumerate([(options_widget.value,options_widget.description)\
                            for options_widget in options_widget.children if options_widget.value]):
    print (enu)
    print (i)

# %%
def changed(b):
    #checked = [options_widget.description for options_widget in options_widget.children if options_widget.value]
    #print (checked)
    descriptions = [i for i in df1[df1['Group'].isin(listofcheckboxes['fruits'])]['Food Name']][0:5]
    options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}
    options = [options_dict[description] for description in descriptions]
    options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})
        
    for enu,i in enumerate([(options_widget.value,options_widget.description)\
                            for options_widget in options_widget.children if options_widget.value]):
        if i[0]==True:
            mass_widget = widgets.IntSlider(description='Mass (grams)', min=0,
                max = 1000,step=50,value=0,disabled=False)              
            multi_select_new = widgets.HBox(children = [options_widget,mass_widget], layout={'overflow': 'scroll'})            
        
        else:
            multi_select_new = widgets.HBox(children = [options_widget,mass_widget], layout={'overflow': 'scroll'}) 
    return multi_select_new

# %%
options_widget

# %%
options_widget.observe(changed)

# %%
multi_select_new

# %%
options_widget

# %%
foodgroups = widgets.Dropdown(options = listofcheckboxes.keys())
descriptions = [i for i in df1[df1['Group'].isin(listofcheckboxes['fruits'])]['Food Name']]
options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}
options = [options_dict[description] for description in descriptions]
options_widget = widgets.VBox(options, layout={'overflow': 'scroll'}) 

mass_dict = {description: widgets.IntSlider(description='Mass (grams)', min=0,
                max = 1000,step=50,value=0,disabled=False) for description in descriptions}
mass = [mass_dict[description] for description in descriptions]
mass_widget = widgets.VBox(mass, layout={'overflow': 'scroll'})
multi_select = widgets.HBox(children = [foodgroups,options_widget,mass_widget], layout={'overflow': 'scroll'})

# %%
def notebook_interaction(self, display=True):
    """Creates interactive notebook widgets for all component parameters,
    if available.
    Requires `ipywidgets` to be installed.
    Parameters
    ----------
    display : bool
        if True (default), attempts to display the widgets.
        Otherwise returns the formatted widget object.
    """
    from ipywidgets import (Checkbox, VBox)
    from traitlets import TraitError as TraitletError
    from IPython.display import display as ip_display
    try:
        active = Checkbox(description='active', value=self.active)
 
        def on_active_change(change):
            self.active = change['new']
        active.observe(on_active_change, names='value')
 
        container = VBox([active])
        for parameter in self.parameters:
            container.children += parameter.notebook_interaction(False),
 
        if not display:
            return container
        ip_display(container)
    except TraitletError:
        if display:
            _logger.info('This function is only avialable when running in'
                         ' a notebook')
        else:
            raise

# %%
multi_select

# %%
[multi_widget.description for multi_widget in multi_widget.children[1].children if multi_widget.value]

# %%
[widgetname.description for widgetname in widgetname.children[0].children if widgetname.value]

# %%
options_widget

# %%
options_widget.value

# %%
widget1 = on_text_change(foodgroups.value)
widget1

# %%
stop

# %%
# HIDDEN
def multi_checkbox_widget(group):
    """ Widget with a search field and lots of checkboxes """
    foodgroups = widgets.Dropdown(options = listofcheckboxes.keys())
    #options_dict = {description: widgets.Checkbox(description=description, value=False) for 
    #                description in descriptions}
    #options = [options_dict[description] for description in descriptions]
    #options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})

    #mass_dict = {description: widgets.IntSlider(description='Mass (grams)', min=0,
    #            max = 1000,step=50,value=0,disabled=False) for description in descriptions}
    #mass = [mass_dict[description] for description in descriptions]
    #mass_widget = widgets.VBox(mass, layout={'overflow': 'scroll'})
    #multi_select = widgets.HBox(children = [foodgroups,options_widget,mass_widget], layout={'overflow': 'scroll'})
    #multi_select = widgets.VBox([options_widget])

    # Wire the search field to the checkboxes
    def on_text_change(change):
        search_input = change['new']
        if search_input == 'no preferences':
            # Reset search field
            pass
            #new_options = [options_dict[description] for description in descriptions]
        else:
            descriptions = [i for i in df1[df1['Group'].isin(group)]['Food Name']]
            options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}
            options = [options_dict[description] for description in descriptions]
            options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})         
            
            #options_widget.children = options
            # Filter by search field using difflib.
            #close_matches = difflib.get_close_matches(search_input, descriptions, cutoff=0.0)
            #new_options = [options_dict[description] for description in close_matches]
        #options_widget.children = new_options

    foodgroups.observe(on_text_change, names='value')
    return multi_select
# words = list(set([i.split(',')[0] for i in df1[df1['Group']=='FAT']['Food Name'].tolist()]))
# widget = multi_checkbox_widget(words)
# [widget.description for widget in widget.children[1].children if widget.value]

# %%
widget1 = multi_checkbox_widget(listofcheckboxes['vegetarianproducts'])
widget1

# %%
widget1 = multi_checkbox_widget(listofcheckboxes['vegetarianproducts'])
widget

# %%
words = [i for i in df_foods[df_foods['Group'].isin(listofcheckboxes['vegetarianproducts'])]['Food Name']]
widget1 = multi_checkbox_widget(words)
widget1

# %%
widget10 = multi_checkbox_widget([i for i in df_foods[df_foods['Group'].isin(listofcheckboxes['vegetarianproducts'])]['Food Name']],listofcheckboxes['fruits'])

# %%
widget10

# %%
listofcheckboxes = {'no preferences':[0],'fruits':['FAT'],'vegetables':['DGR','DGC'],
     'legumes':['DBR','DBC','DFR','DFC'],'grains':['AC','AC_wg','DAR','DAC',
     'AI','AI_wg','AA','AA_wg','AF','AF_wg','AD','AD_wg','AC','AC_wg'],'nuts_seeds':
     ['GAT'],'milk':['BAE','BAH','BAK','BLS','BLM','BLH','BLF','BN'],
     'vegetarianproducts':['BAV','BNV','VEG'],
     'fish':['JAC', 'JAR', 'JCC', 'JCR', 'JKC', 'JKR', 'JMC', 'JMR', 'JRC'],
    'meat':['MBGR','MBGC','MACR','MACC','MAER','MECC','MECR','MEER','MEEC','MAIC','MAIR','MAE',\
    'MAIR','MAIC','MCOR','MCOC','MCAR','MCAC','MAGR','MAGC','MAHR','MAHC',
    'MI','MAAC','MAAR'],'eggs_oil':['CA','OA', 'OC', 'OE','BTM','BJC']}

# %%
# HIDDEN
def joinlists(widgetname):
    rs1 = [widgetname.description for widgetname in widgetname.children[0].children if widgetname.value]
    rs2 = [widgetname.value for widgetname in widgetname.children[1].children if widgetname.value]
    food = list(zip(rs1,rs2))
    return food

# %%
foodgroups = widgets.Dropdown(options = listofcheckboxes.keys())
display(foodgroups)

# %%
descriptions = [i for i in df1[df1['Group'].isin(listofcheckboxes['fruits'])]['Food Name']]

# %%
descriptions[0:2]

# %%
options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}

# %%
options = [options_dict[description] for description in descriptions]

# %%
options[0:2]

# %%
options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})

# %%
mass_dict = {description: widgets.IntSlider(description='Mass (grams)', min=0,
                max = 1000,step=50,value=0,disabled=False) for description in descriptions}
mass = [mass_dict[description] for description in descriptions]
mass_widget = widgets.VBox(mass, layout={'overflow': 'scroll'})

# %%
foodgroups.value

# %%
def whentextischanged(change):
    search_input = foodgroups.value
    descriptions = [i for i in df1[df1['Group'].isin(foodgroups.value)]['Food Name']]
    options_dict = {description: widgets.Checkbox(description=description, value=False) for 
                    description in descriptions}
    options = [options_dict[description] for description in descriptions]
    options_widget = widgets.Vbox(options, layout={'overflow': 'scroll'})

# %%
multi_select = widgets.HBox(children = [foodgroups,options_widget,mass_widget], layout={'overflow': 'scroll'})

# %%
foodgroups.observe(whentextischanged,names = 'value')

# %%
foodgroups.observe(whentextischanged,names = 'value')

# %%
def on_text_change(change):
    if foodgroups.value =='fruits':
        words = [i for i in df_foods[df_foods['Group'].isin(listofcheckboxes['fruits'])]['Food Name']]
        new_options =  [options_dict[description] for description in descriptions]
    else:
        pass
        
    options_widget.children = new_options

# %%
options_widget.observe(on_text_change, names='value')

# %%
top_toggle.observe(remove_3, names='value')
display(top_toggle)
display(vb)

# %%
words = [i for i in df_foods[df_foods['Group'].isin(listofcheckboxes['vegetarianproducts'])]['Food Name']]
widget1 = multi_checkbox_widget(words)
widget1

# %%
words = [i for i in df_foods[df_foods['Group'].isin(listofcheckboxes['vegetarianproducts'])]['Food Name']]
widget1 = multi_checkbox_widget(words)
widget1

# %%
vegetarianproducts = joinlists(widget1)

# %%
#vegetarianproducts = [widget.description for widget in widget.children[0].children if widget.value]

# %%
words = [i for i in df1[df1['Group'].isin(listofcheckboxes['eggs_oil'])]['Food Name']]
widget2 = multi_checkbox_widget(words)
widget2

# %%
eggs_oil = joinlists(widget2)

# %%
words = [i for i in df1[df1['Group'].isin(listofcheckboxes['fish'])]['Food Name']]
widget3 = multi_checkbox_widget(words)
widget3

# %%
fish = joinlists(widget3)

# %%
words = [i for i in df1[df1['Group'].isin(listofcheckboxes['meat'])]['Food Name']]
widget4 = multi_checkbox_widget(words)
widget4

# %%
meat = joinlists(widget4)

# %%
words = [i for i in df1[df1['Group'].isin(listofcheckboxes['fruits'])]['Food Name']]
widget5 = multi_checkbox_widget(words)
widget5

# %%
fruit = joinlists(widget5)

# %%
fruit

# %%
words = [i for i in df1[df1['Group'].isin(listofcheckboxes['vegetables'])]['Food Name']]
widget6 = multi_checkbox_widget(words)
widget6

# %%
vegetables = joinlists(widget6)

# %%
words = [i for i in df1[df1['Group'].isin(listofcheckboxes['legumes'])]['Food Name']]
widget7 = multi_checkbox_widget(words)
widget7

# %%
legumes = joinlists(widget7)

# %%
words = [i for i in df1[df1['Group'].isin(listofcheckboxes['grains'])]['Food Name']]
widget8 = multi_checkbox_widget(words)
widget8

# %%
grains = joinlists(widget8)

# %%
words = [i for i in df1[df1['Group'].isin(listofcheckboxes['milk'])]['Food Name']]
widget9 = multi_checkbox_widget(words)
widget9

# %%
milk = joinlists(widget9)

# %%
selectedfoods = {}
for i in [vegetarianproducts,eggs_oil,fish,meat,fruit,vegetables,legumes,grains,milk]:
    for j in i:
        selectedfoods[j[0].split(',')[0]] = {}#'names'
        selectedfoods[j[0].split(',')[0]]['names']=j[0]
        selectedfoods[j[0].split(',')[0]]['mass']=j[1]

# %%
selectedfoods

# %%
runcode5 = widgets.Button(description='Run Tool')
output5 = widgets.Output()
def run_tool(b):
    global df_opt
    with output5:
        ipython.magic('run Optimization_Tool_Online.ipynb')
        df_opt = runopt(df_foods,imp.value,diettype.value,sup.value,gen.value,personweight.value,\
                          height.value,age.value,act.value,days.value,2,selectedfoods)
        return df_opt
display(runcode5,output5)
runcode5.on_click(run_tool)
