# %%
import numpy as np
import pandas as pd
import os
import math
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
from cn.protect import Protect
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-0239edbebccd> in <module>
# ----> 1 from cn.protect import Protect
#
# ModuleNotFoundError: No module named 'cn'

# %%
# input files from other python scripts
data_dir = os.path.join('..','nb1','Input')
data_trade = os.path.join('..','nb1','Trade')

# %%
other_impacts = pd.read_excel(os.path.join(data_dir,'otherimpacts.xlsx'))
other_impacts.reset_index(inplace=True,drop=True)

# %%
other_impacts
# Out:
#      Unnamed: 0                                               key  \
# 0             0  ('cutoff35', '668014867e4919dae2c88bc5bba6e659')
# 1             1  ('cutoff35', '100aaec2edf691a5d218579c85f07b2d')
# 2             2  ('cutoff35', '0a2d1790a0adf3dd09b64e2e3a36caf5')
# 3             3  ('cutoff35', 'd2e7144f3cbfaf96f442b6fc7ac93628')
# 4             4  ('cutoff35', 'a4ff619bc2e4a23563b9a81c1d9cd437')
# ..          ...                                               ...
# 246         246  ('cutoff35', '028989a699c2f81a8db4c0833ebc068b')
# 247         247                                           average
# 248         248                                           average
# 249         249                                           average
# 250         250                                           average
#
#                                                   name country           unit  \
# 0         market group for electricity, medium voltage     GLO  kilowatt hour
# 1    market for heat, from steam, in chemical industry     RoW      megajoule
# 2    market for heat, from steam, in chemical industry     RER      megajoule
# 3               market for electricity, medium voltage      RS  kilowatt hour
# 4               market for electricity, medium voltage      TR  kilowatt hour
# ..                                                 ...     ...            ...
# 246  market for transport, freight, lorry with refr...     GLO  ton kilometer
# 247             market for electricity, medium voltage      CA  kilowatt hour
# 248             market for electricity, medium voltage      US  kilowatt hour
# 249             market for electricity, medium voltage      IN  kilowatt hour
# 250             market for electricity, medium voltage      CN  kilowatt hour
#
#           GHG
# 0    0.736664
# 1    0.122257
# 2    0.102864
# 3    0.867512
# 4    0.655934
# ..        ...
# 246  0.606738
# 247  0.413109
# 248  0.680355
# 249  1.314365
# 250  0.869499
#
# [251 rows x 6 columns]
